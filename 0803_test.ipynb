# %% [markdown]
# ## reference
#  * [偷偷說爬蟲by Go](https://city.shaform.com/zh/2019/01/11/plurk-crawler/)
#  * [Requests Docs](https://2.python-requests.org/en/master/api)
#  * [bs4 Docs](https://www.crummy.com/software/BeautifulSoup/bs4/doc)
#  * [bs4 simple intro](https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/2/)
#  * [Plurk API 2.0](https://www.plurk.com/API)

# %%
# import packages
from __future__ import print_function

from mdutils.mdutils import MdUtils # help to create a markdown file
from bs4 import BeautifulSoup as bs # for html parsing
import requests as rq
import slimit
from slimit.parser import Parser
from slimit.visitors.nodevisitor import ASTVisitor

# %% [markdown]
# ### 0803 - testing
# > Little Goal: input plurk link and get some md

# %%
"""
" A Visitor inheritate slimit.visitors.ASTVisitor.
" To traverse the parse tree and transform to python dictionary
"""
class JSVisitor(ASTVisitor):
    def __init__(self, dic):
        self.json = dic
    """
    "  Traverse function
    """
    def visit_Object(self, node):
        for prop in node:
            left, right = prop.left, prop.right
            key = left.value[1:-1]   # deliminate quotes
            try:
                value = self.GetValue(right)
            except ValueError as e:
                print("ValueError: {}".format(str(e)))
            # print("Property key={}, value={}".format(key, value))
            self.json[key] = value
            # visit all children in turn
            self.visit(prop)
    """
    "  To get and transform values from AST nodes.
    """    
    def GetValue(self, node):
        node_type = type(node)
        if node_type is slimit.ast.NewExpr:
            return "NewExpr"
        if node_type is slimit.ast.Boolean:
            if node.value == 'false':
                return False
            if node.value == 'true':
                return True
            raise ValueError("Unknow value of node: {}".format(node.value))
        if node_type is slimit.ast.String:
            return node.value[1:-1]   # deliminate quotes
        if node_type is slimit.ast.Number:
            return int(node.value)
        if node_type is slimit.ast.Null:
            return None
        if node_type is slimit.ast.Array:
            array = [self.GetValue(n) for n in node.items]
            return array
        raise ValueError("Unknow node type: {}".format(node_type))

# %%
def get_content_by_link(plurk_url):
    
    # request plurk content from plurk.com
    with rq.Session() as sess:    
        plurk = sess.get(plurk_url)
        if plurk.status_code == rq.codes.ok:
            print("Request Success! Status: {}.".format(plurk.status_code))
        else:
            print("Request fail. Status: {}.".format(plurk.status_code))
            return 'Fail QAQ'
            
    # read content of HTML
    soup = bs(plurk.text)
    # extract the last script out
    script = soup.find_all("script")[-1].string
    
    plurk_content = {}

    parser = Parser()
    json_tree = parser.parse(script)    # construct parse tree
    visitor = JSVisitor(plurk_content)
    visitor.visit(json_tree)            # traverse the tree

    # response
    request_url = "https://www.plurk.com/Responses/get"
    data = {'plurk_id': plurk_content.get('id'), 'from_response_id': '0'}
    print(data)
    
    with rq.Session() as sess:
        # request response from Responses/get, and use plurk_id as data to tell website which plurk we are requesting
        # sess.post means HTTP POST
        response = sess.post(request_url, data=data)
        if response.status_code == rq.codes.ok:
            print("Request Success! Status: {}.".format(response.status_code))
        else:
            print("Request fail. Status: {}.".format(response.status_code))
    
    response_content = response.json()
    return plurk_content, soup, response_content

# %%
##################### 
#                   #
#   Main Function   #
#                   #
##################### 
def get_raw_plurk(link):
    plurk_info, plurk_html, content = get_content_by_link(link)

    head = plurk_html.find_all("div", class_="plurk")  
    string = ''
    for owo in head[0].find("div", class_="text_holder"):
        string += str(owo)  

    raw_data = {
        "plurk_info": {
            "plurk_id":plurk_info.get('id'),
            "user_id":plurk_info.get('user_id'),
            "favorite_count":plurk_info.get('favorite_count'),
            "response_count":plurk_info.get('response_count'),
            "replurkers_count":plurk_info.get('replurkers_count'),
            "coins":plurk_info.get('coins'),
            "qualifier":plurk_info.get('qualifier'),
            "anonymous":plurk_info.get('anonymous'),
            "st_edited":plurk_info.get('st_edited'),
            "no_comments":plurk_info.get('no_comments'),
            "posted":plurk_info.get('posted'),
            "lang":plurk_info.get('lang'),
            "content":plurk_info.get('content'),
            "content_raw":plurk_info.get('content_raw'),
        },
        "plurk":{
            "poster_img": head[0].find("img").get("src"),
            "poster_name": head[0].find("a", class_="name").text,
            "post_time": head[0].find("time", class_="timeago")['datetime'],
            "post_content": string,
            "response_count": content.get('response_count')        
        },
        "response":[]
    }


    users = content.get('users')
    for response in content.get('responses'):
        user_id = str(response.get('user_id'))

        # user profile image
        has_profile_image = users.get(user_id).get('has_profile_image')
        avatar = users.get(user_id).get('avatar')
        if has_profile_image == 1 and avatar != None:
            user_img = "https://avatars.plurk.com/" + user_id + "-small"+str(avatar)+".gif"
        elif has_profile_image == 1 and avatar == None:
            user_img = "https://avatars.plurk.com/" + user_id + "-small.gif"
        else:
            user_img = "https://www.plurk.com/static/default_small.gif"

        # every response 
        raw_data['response'].append({
            "user_id": user_id,
            "user_img": user_img,
            "user_name": users.get(user_id).get('display_name'),
            "name_color": users.get(user_id).get('name_color'),
            "content": response.get('content_raw'),
            "posted":response.get('posted')
        })

    return raw_data

# %%
url = input('Plurk url: ')
raw_data = get_raw_plurk(url)
raw_data
# Out:
# Plurk url: https://www.plurk.com/p/negxzt
# Request Success! Status: 200.
# {'plurk_id': 1415027225, 'from_response_id': '0'}
# Request Success! Status: 200.
# {'plurk_info': {'plurk_id': 1415027225,
#   'user_id': 4898180,
#   'favorite_count': 206,
#   'response_count': 82,
#   'replurkers_count': 161,
#   'coins': 0,
#   'qualifier': ':',
#   'anonymous': False,
#   'st_edited': None,
#   'no_comments': 0,
#   'posted': 'NewExpr',
#   'lang': 'tr_ch',
#   'content': '\\u6211\\u5011\\u6709\\u65b0\\u529f\\u80fd\\u4e86\\uff0c\\u76ee\\u524d\\u5148\\u958b\\u653e\\u5657\\u5e63\\u4f7f\\u7528\\u8005\\u6e2c\\u8a66<br /><a href=\\"https://www.plurk.com/p/negxv7\\" class=\\"ex_link meta plink\\" rel=\\"nofollow\\"><img src=\\"https://avatars.plurk.com/4203050-medium10.gif\\" height=\\"40px\\">@plurktaiwan - \\u65b0\\u529f\\u80fd\\uff1a\\u8cc7\\u6e90\\u56de\\u6536\\u6876 - \\u958b\\u653e\\u5657\\u5e63\\u4f7f\\u7528\\u8005\\u6e2c\\u8a66\\u4e2d\\u64c1\\u6709\\u5657\\u5e63\\u5c07\\u6703\\u9810\\u8a2d\\u555f\\u7528\\u8cc7\\u6e90\\u56de\\u6536\\u6876...</a>',
#   'content_raw': '\\u6211\\u5011\\u6709\\u65b0\\u529f\\u80fd\\u4e86\\uff0c\\u76ee\\u524d\\u5148\\u958b\\u653e\\u5657\\u5e63\\u4f7f\\u7528\\u8005\\u6e2c\\u8a66\\nhttps://www.plurk.com/p/negxv7'},
#  'plurk': {'poster_img': 'https://avatars.plurk.com/4898180-medium2.gif',
#   'poster_name': '噗浪技術部🛠',
#   'post_time': '2019-07-12T03:16:03Z',
#   'post_content': '我們有新功能了，目前先開放噗幣使用者測試<br/><a class="ex_link meta plink" href="https://www.plurk.com/p/negxv7" rel="nofollow"><img height="40px" src="https://avatars.plurk.com/4203050-medium10.gif"/>@plurktaiwan - 新功能：資源回收桶 - 開放噗幣使用者測試中擁有噗幣將會預設啟用資源回收桶...</a>',
#   'response_count': 82},
#  'response': [{'user_id': '4317654',
#    'user_img': 'https://avatars.plurk.com/4317654-small2.gif',
#    'user_name': '天晴雲白',
#    'name_color': None,
#    'content': '[em006]',
#    'posted': 'Fri, 12 Jul 2019 03:16:22 GMT'},
#   {'user_id': '6451895',
#    'user_img': 'https://avatars.plurk.com/6451895-small19660326.gif',
#    'user_name': '夏色恋彩得蘇',
#    'name_color': 'FFA59A',
#    'content': '[emo167]',
#    'posted': 'Fri, 12 Jul 2019 03:18:37 GMT'},
#   {'user_id': '4286607',
#    'user_img': 'https://avatars.plurk.com/4286607-small5027502.gif',
#    'user_name': '咩咩楓🌈一起活到春暖花開',
#    'name_color': 'FFA59A',
#    'content': '感謝ㄐㄐ!!!想再次求網頁版全部標示已讀可以跟APP一樣有再次確認的部分  真的會不小心誤按',
#    'posted': 'Fri, 12 Jul 2019 03:19:08 GMT'},
#   {'user_id': '3966154',
#    'user_img': 'https://avatars.plurk.com/3966154-small21321610.gif',
#    'user_name': '≡♥)`ν゜)ｸﾞｼｬ🌈少爺',
#    'name_color': '63C6D3',
#    'content': '一天又愉快地開始了，感謝ㄐㄐs的努力！',
#    'posted': 'Fri, 12 Jul 2019 03:20:20 GMT'},
#   {'user_id': '13867830',
#    'user_img': 'https://avatars.plurk.com/13867830-small20730520.gif',
#    'user_name': '風靈⍢CWT C28.29',
#    'name_color': '2264D6',
#    'content': '偷偷跟ㄐㄐ許願(?)有一天能有排程發文的功能[emo548]',
#    'posted': 'Fri, 12 Jul 2019 03:20:23 GMT'},
#   {'user_id': '6845351',
#    'user_img': 'https://avatars.plurk.com/6845351-small23286257.gif',
#    'user_name': 'CWT52-Q32✨冬彌✨',
#    'name_color': '63C6D3',
#    'content': '想許願預約發噗功能',
#    'posted': 'Fri, 12 Jul 2019 03:20:36 GMT'},
#   {'user_id': '3585860',
#    'user_img': 'https://avatars.plurk.com/3585860-small6.gif',
#    'user_name': '小 兔',
#    'name_color': '2264D6',
#    'content': '希望有常用表符清單....',
#    'posted': 'Fri, 12 Jul 2019 03:21:06 GMT'},
#   {'user_id': '8433188',
#    'user_img': 'https://avatars.plurk.com/8433188-small21766629.gif',
#    'user_name': '千年樹妖',
#    'name_color': '86CA6F',
#    'content': '[有神快拜]',
#    'posted': 'Fri, 12 Jul 2019 03:21:59 GMT'},
#   {'user_id': '4672862',
#    'user_img': 'https://avatars.plurk.com/4672862-small21277889.gif',
#    'user_name': '溺✿D1-M24寄生',
#    'name_color': 'E41227',
#    'content': '預約發噗功能同求+1.........................[lie_3]',
#    'posted': 'Fri, 12 Jul 2019 03:23:57 GMT'},
#   {'user_id': '4719248',
#    'user_img': 'https://avatars.plurk.com/4719248-small22981983.gif',
#    'user_name': '鈴☆ﾟ.*･｡',
#    'name_color': '63C6D3',
#    'content': '預約發噗+1',
#    'posted': 'Fri, 12 Jul 2019 03:26:29 GMT'},
#   {'user_id': '4004950',
#    'user_img': 'https://avatars.plurk.com/4004950-small4.gif',
#    'user_name': '🐱LHT😼',
#    'name_color': '2264D6',
#    'content': '--太久沒上線 發送死亡留言噗之類的--',
#    'posted': 'Fri, 12 Jul 2019 03:26:48 GMT'},
#   {'user_id': '8543421',
#    'user_img': 'https://avatars.plurk.com/8543421-small9457908.gif',
#    'user_name': '荷包蛋⦿沉迷MJ無法自拔',
#    'name_color': 'E8AF37',
#    'content': '許願排程發噗!![emo26]',
#    'posted': 'Fri, 12 Jul 2019 03:28:34 GMT'},
#   {'user_id': '5323764',
#    'user_img': 'https://avatars.plurk.com/5323764-small13448660.gif',
#    'user_name': '⭕️曦〞/ SAN值不穩定。',
#    'name_color': '63C6D3',
#    'content': '@LHT2: 這個感覺不錯[69]',
#    'posted': 'Fri, 12 Jul 2019 03:29:14 GMT'},
#   {'user_id': '10437130',
#    'user_img': 'https://avatars.plurk.com/10437130-small22118305.gif',
#    'user_name': '電波Cvayi',
#    'name_color': None,
#    'content': 'ㄐㄐ辛苦了 [emo582] \n想順便許願宣傳用河道(今早看到的',
#    'posted': 'Fri, 12 Jul 2019 03:30:55 GMT'},
#   {'user_id': '4122181',
#    'user_img': 'https://avatars.plurk.com/4122181-small32.gif',
#    'user_name': '翎翊@狂氣の星神柴羔Δ懶†',
#    'name_color': 'E41227',
#    'content': '[膜拜]',
#    'posted': 'Fri, 12 Jul 2019 03:30:55 GMT'},
#   {'user_id': '6200037',
#    'user_img': 'https://avatars.plurk.com/6200037-small4.gif',
#    'user_name': '更銘✿',
#    'name_color': 'FF9B65',
#    'content': '新功能!!',
#    'posted': 'Fri, 12 Jul 2019 03:32:42 GMT'},
#   {'user_id': '5676522',
#    'user_img': 'https://avatars.plurk.com/5676522-small54.gif',
#    'user_name': '❄銀雪∞',
#    'name_color': '86CA6F',
#    'content': '許願排程發噗+1，還有小投票（大概最多四選一應該夠，二選一有點侷限，或者可以更多）\n另外paste希望可以像圖片一樣管理刪除（有時候改個東西就要建立新的，舊的還是繼續流傳[emo281]',
#    'posted': 'Fri, 12 Jul 2019 03:32:46 GMT'},
#   {'user_id': '8204555',
#    'user_img': 'https://avatars.plurk.com/8204555-small32.gif',
#    'user_name': '阿灼◀工作室小社畜',
#    'name_color': '0A9C17',
#    'content': '許願排程發布噗+1 😍',
#    'posted': 'Fri, 12 Jul 2019 03:33:40 GMT'},
#   {'user_id': '8842798',
#    'user_img': 'https://avatars.plurk.com/8842798-small22425500.gif',
#    'user_name': '⎝大衛天然有毒🐍老千⎠',
#    'name_color': 'E41227',
#    'content': '趁機許願投票功能[怪表情_482]',
#    'posted': 'Fri, 12 Jul 2019 03:33:43 GMT'},
#   {'user_id': '4472878',
#    'user_img': 'https://avatars.plurk.com/4472878-small22920939.gif',
#    'user_name': '影喰い🍊🌱CWT首日T12',
#    'name_color': None,
#    'content': '許願投票功能！！！',
#    'posted': 'Fri, 12 Jul 2019 03:34:11 GMT'},
#   {'user_id': '6025188',
#    'user_img': 'https://avatars.plurk.com/6025188-small106.gif',
#    'user_name': '十根刺(mein)',
#    'name_color': 'BA8FBE',
#    'content': '許願投票功能+1！！！！[emo266]',
#    'posted': 'Fri, 12 Jul 2019 03:34:27 GMT'},
#   {'user_id': '4711100',
#    'user_img': 'https://avatars.plurk.com/4711100-small20.gif',
#    'user_name': 'smile_Q 🗝🌌🌏✏',
#    'name_color': None,
#    'content': '希望能filter別人跟自己的私人噗，有時只想找看自己的私人噗~',
#    'posted': 'Fri, 12 Jul 2019 03:35:55 GMT'},
#   {'user_id': '5750216',
#    'user_img': 'https://avatars.plurk.com/5750216-small22087064.gif',
#    'user_name': '海鹽可可拿鐵♔女王',
#    'name_color': '63C6D3',
#    'content': '喔喔喔喔喔喔',
#    'posted': 'Fri, 12 Jul 2019 03:37:17 GMT'},
#   {'user_id': '8575770',
#    'user_img': 'https://avatars.plurk.com/8575770-small22447416.gif',
#    'user_name': '書語✠always be me',
#    'name_color': 'FF9B65',
#    'content': '書籤其實很好用',
#    'posted': 'Fri, 12 Jul 2019 03:39:44 GMT'},
#   {'user_id': '4717834',
#    'user_img': 'https://avatars.plurk.com/4717834-small126.gif',
#    'user_name': 'ましろ',
#    'name_color': 'BA8FBE',
#    'content': '不能刪除留言功能+1',
#    'posted': 'Fri, 12 Jul 2019 03:41:29 GMT'},
#   {'user_id': '5632733',
#    'user_img': 'https://avatars.plurk.com/5632733-small16099415.gif',
#    'user_name': 'betty3572🐞',
#    'name_color': 'FFA59A',
#    'content': 'filter自己跟別人的私噗、回應過的噗+1',
#    'posted': 'Fri, 12 Jul 2019 03:41:38 GMT'},
#   {'user_id': '1141360',
#    'user_img': 'https://avatars.plurk.com/1141360-small10707360.gif',
#    'user_name': 'unit',
#    'name_color': 'FF9B65',
#    'content': '許願投票功能',
#    'posted': 'Fri, 12 Jul 2019 03:41:50 GMT'},
#   {'user_id': '8576483',
#    'user_img': 'https://avatars.plurk.com/8576483-small8.gif',
#    'user_name': '彩(´・ω・`)',
#    'name_color': '63C6D3',
#    'content': '噗幣表符儲存上限增加 --收集狂表示不夠用--',
#    'posted': 'Fri, 12 Jul 2019 03:43:04 GMT'},
#   {'user_id': '10615175',
#    'user_img': 'https://avatars.plurk.com/10615175-small2.gif',
#    'user_name': '殉@年輕人終究是年輕人',
#    'name_color': 'E41227',
#    'content': '許願投票功能+1',
#    'posted': 'Fri, 12 Jul 2019 03:43:06 GMT'},
#   {'user_id': '9416724',
#    'user_img': 'https://avatars.plurk.com/9416724-small22333621.gif',
#    'user_name': '大哼堡',
#    'name_color': 'E8AF37',
#    'content': '許願限時投票功能[emo5796]',
#    'posted': 'Fri, 12 Jul 2019 03:44:37 GMT'},
#   {'user_id': '8589624',
#    'user_img': 'https://avatars.plurk.com/8589624-small21805159.gif',
#    'user_name': '♡✨翎雲✦°♬',
#    'name_color': '86CA6F',
#    'content': '投票跟上傳短影片功能',
#    'posted': 'Fri, 12 Jul 2019 03:48:00 GMT'},
#   {'user_id': '14524731',
#    'user_img': 'https://avatars.plurk.com/14524731-small18539555.gif',
#    'user_name': '飄 / 棄號倒數100天',
#    'name_color': '63C6D3',
#    'content': '感謝ㄐㄐ!!!!!太好用了我喜歡!!!!',
#    'posted': 'Fri, 12 Jul 2019 03:48:44 GMT'},
#   {'user_id': '4832390',
#    'user_img': 'https://avatars.plurk.com/4832390-small14546387.gif',
#    'user_name': 'MC.HERMES❤🐎月泠。',
#    'name_color': '63C6D3',
#    'content': '許願投票功能 [emo2204] \n還有跳到第一則回應TT!!',
#    'posted': 'Fri, 12 Jul 2019 03:49:29 GMT'},
#   {'user_id': '5895594',
#    'user_img': 'https://avatars.plurk.com/5895594-small4.gif',
#    'user_name': '我家洛基只是出去旅行了',
#    'name_color': '63C6D3',
#    'content': '預約發噗+1',
#    'posted': 'Fri, 12 Jul 2019 03:49:32 GMT'},
#   {'user_id': '9389687',
#    'user_img': 'https://avatars.plurk.com/9389687-small13103255.gif',
#    'user_name': '低產炭',
#    'name_color': None,
#    'content': '許願自訂分類河道的功能[emo11062652826]（好友、追隨等等的',
#    'posted': 'Fri, 12 Jul 2019 03:50:33 GMT'},
#   {'user_id': '4800087',
#    'user_img': 'https://avatars.plurk.com/4800087-small136.gif',
#    'user_name': '打什麼打',
#    'name_color': None,
#    'content': '希望能有投票功能[emo9]',
#    'posted': 'Fri, 12 Jul 2019 03:52:16 GMT'},
#   {'user_id': '7966478',
#    'user_img': 'https://avatars.plurk.com/7966478-small23311164.gif',
#    'user_name': '清水🦋忍住不買娃',
#    'name_color': 'BA8FBE',
#    'content': '求有上傳影片功能',
#    'posted': 'Fri, 12 Jul 2019 03:53:38 GMT'},
#   {'user_id': '14938433',
#    'user_img': 'https://avatars.plurk.com/14938433-small17764788.gif',
#    'user_name': '丁Tei',
#    'name_color': 'FFA59A',
#    'content': '[emo15]許願轉噗前提示功能！不然有時候誤轉超尷尬',
#    'posted': 'Fri, 12 Jul 2019 03:54:49 GMT'},
#   {'user_id': '4463190',
#    'user_img': 'https://avatars.plurk.com/4463190-small10.gif',
#    'user_name': 'Yoshiki',
#    'name_color': 'E41227',
#    'content': '希望有河道分LIST功能',
#    'posted': 'Fri, 12 Jul 2019 03:54:58 GMT'},
#   {'user_id': '6142666',
#    'user_img': 'https://avatars.plurk.com/6142666-small22349786.gif',
#    'user_name': '小熊海參| ᐕ)\u202a❥染鶴',
#    'name_color': 'E8AF37',
#    'content': '噗幣表符儲存上限增加+1 [emo1039]  ',
#    'posted': 'Fri, 12 Jul 2019 03:57:49 GMT'},
#   {'user_id': '8758608',
#    'user_img': 'https://avatars.plurk.com/8758608-small4.gif',
#    'user_name': '(* ´ ▽ ` )ﾉ',
#    'name_color': '2264D6',
#    'content': '投票+1',
#    'posted': 'Fri, 12 Jul 2019 03:59:31 GMT'},
#   {'user_id': '10789393',
#    'user_img': 'https://avatars.plurk.com/10789393-small23117877.gif',
#    'user_name': '鼊鳳狂潮逼⎝（´◔౪◔）⎠',
#    'name_color': '63C6D3',
#    'content': '希望能有特別關注加星號噗友發的噗～',
#    'posted': 'Fri, 12 Jul 2019 03:59:32 GMT'},
#   {'user_id': '3419089',
#    'user_img': 'https://avatars.plurk.com/3419089-small678165.gif',
#    'user_name': '海參(・◡・)',
#    'name_color': None,
#    'content': '投票 (woot)',
#    'posted': 'Fri, 12 Jul 2019 04:00:19 GMT'},
#   {'user_id': '3460202',
#    'user_img': 'https://avatars.plurk.com/3460202-small10.gif',
#    'user_name': '鹹魚飯小喵',
#    'name_color': None,
#    'content': '許願投票功能></',
#    'posted': 'Fri, 12 Jul 2019 04:02:25 GMT'},
#   {'user_id': '8607134',
#    'user_img': 'https://avatars.plurk.com/8607134-small82.gif',
#    'user_name': '羞蘿犬★EX熊貓長存我心',
#    'name_color': None,
#    'content': '跳到第一層回應+1\n回應太多的噗不方便看 [emo529] ',
#    'posted': 'Fri, 12 Jul 2019 04:04:31 GMT'},
#   {'user_id': '3888010',
#    'user_img': 'https://avatars.plurk.com/3888010-small36.gif',
#    'user_name': '七曜',
#    'name_color': 'E8AF37',
#    'content': '強烈許願【只看好友訊息】的功能……',
#    'posted': 'Fri, 12 Jul 2019 04:06:41 GMT'},
#   {'user_id': '9899013',
#    'user_img': 'https://avatars.plurk.com/9899013-small21591106.gif',
#    'user_name': '🌈灰(๑˙ ˙)',
#    'name_color': 'BA8FBE',
#    'content': '許願預約發噗！\n技技辛苦了 [emo1_3] ',
#    'posted': 'Fri, 12 Jul 2019 04:06:51 GMT'},
#   {'user_id': '6014566',
#    'user_img': 'https://avatars.plurk.com/6014566-small15026271.gif',
#    'user_name': 'カ。',
#    'name_color': None,
#    'content': '希望有\n*一鍵全部消音功能\n*遮蔽特定使用者(非黑名單)功能，只是不想看到對方發言，但沒想拉黑。拉黑伴隨仇恨值 [躺_1] ',
#    'posted': 'Fri, 12 Jul 2019 04:11:42 GMT'},
#   {'user_id': '7146655',
#    'user_img': 'https://avatars.plurk.com/7146655-small20093349.gif',
#    'user_name': '🌈盾冬無料寄攤C69❄浮雲飄飄',
#    'name_color': 'BA8FBE',
#    'content': '預約發噗和投票',
#    'posted': 'Fri, 12 Jul 2019 04:12:13 GMT'},
#   {'user_id': '11487320',
#    'user_img': 'https://avatars.plurk.com/11487320-small21729125.gif',
#    'user_name': 'r辰沉塵',
#    'name_color': '63C6D3',
#    'content': '預約發刪鎖噗[emo534131823]',
#    'posted': 'Fri, 12 Jul 2019 04:13:53 GMT'},
#   {'user_id': '9406603',
#    'user_img': 'https://avatars.plurk.com/9406603-small22208582.gif',
#    'user_name': '椰可❖草青',
#    'name_color': '63C6D3',
#    'content': '好奇預約發噗功能是有什麼方便的地方嗎？',
#    'posted': 'Fri, 12 Jul 2019 04:14:50 GMT'},
#   {'user_id': '4380699',
#    'user_img': 'https://avatars.plurk.com/4380699-small42.gif',
#    'user_name': '紐約好鄰居★阿餔辣',
#    'name_color': 'FFA59A',
#    'content': '遮蔽特定使用者只要開好友頁面，把藍色的眼睛按鈕關掉就可以關掉好友河道了～',
#    'posted': 'Fri, 12 Jul 2019 04:17:14 GMT'},
#   {'user_id': '8125870',
#    'user_img': 'https://avatars.plurk.com/8125870-small23068077.gif',
#    'user_name': '企✿我要瘋掉',
#    'name_color': '63C6D3',
#    'content': '@sh98coco: 比如發角色生賀之類的 想在特定時間點發噗的時候 預約發噗會很好用~\n雖然覺得這樣少了一點樂趣😂之前跨年很喜歡掐0:00發噗 偶爾會早了一點點結果變成23:59的噗',
#    'posted': 'Fri, 12 Jul 2019 04:19:58 GMT'},
#   {'user_id': '5581888',
#    'user_img': 'https://avatars.plurk.com/5581888-small6508362.gif',
#    'user_name': '既雨✿CWT/E25.26',
#    'name_color': 'E8AF37',
#    'content': '許願上傳影片的功能><',
#    'posted': 'Fri, 12 Jul 2019 04:21:54 GMT'},
#   {'user_id': '4769192',
#    'user_img': 'https://avatars.plurk.com/4769192-small108.gif',
#    'user_name': 'ミ(●∀´)彡(`Д´、) 苗',
#    'name_color': 'FFA59A',
#    'content': '技技辛苦了!\n也想許願有"噗主可以自行把捏他句子設定為反白或反黑"的功能\n類似像萌娘百科這樣~ \nhttps://images.plurk.com/5DsWMG4sZ9KTKXD6hJbwaP.gif',
#    'posted': 'Fri, 12 Jul 2019 04:23:41 GMT'},
#   {'user_id': '6014566',
#    'user_img': 'https://avatars.plurk.com/6014566-small15026271.gif',
#    'user_name': 'カ。',
#    'name_color': None,
#    'content': '@yuzusvoyage: 不是好友，是很常看到的同圈飯(rofl)  \n而且off並不會連對方在別人噗底下的回覆都遮蔽\n\n是想要有黑名單的作用，但不用讓對方也看不到我，只是單方面的想圖個清靜',
#    'posted': 'Fri, 12 Jul 2019 04:24:23 GMT'},
#   {'user_id': '4382167',
#    'user_img': 'https://avatars.plurk.com/4382167-small10852309.gif',
#    'user_name': '這是一個間諜太子',
#    'name_color': '86CA6F',
#    'content': '許願可以分清楚河道上親友和追蹤到人',
#    'posted': 'Fri, 12 Jul 2019 04:26:06 GMT'},
#   {'user_id': '8019964',
#    'user_img': 'https://avatars.plurk.com/8019964-small1802718.gif',
#    'user_name': 'Faicha✤需要更多特休',
#    'name_color': 'E8AF37',
#    'content': '許願希望可以有標亮同噗內相同帳號所有回應的功能，偷偷說或高樓追起來比較方便 [emo2088] \n現在只能標亮原作者感覺不太夠用',
#    'posted': 'Fri, 12 Jul 2019 04:26:22 GMT'},
#   {'user_id': '8019964',
#    'user_img': 'https://avatars.plurk.com/8019964-small1802718.gif',
#    'user_name': 'Faicha✤需要更多特休',
#    'name_color': 'E8AF37',
#    'content': '同樣許願好友河道，這個分類裡面只看得到所有好友的噗，看不到其他非好友但有追蹤的噗 [emo1236] ',
#    'posted': 'Fri, 12 Jul 2019 04:28:16 GMT'},
#   {'user_id': '14219199',
#    'user_img': 'https://avatars.plurk.com/14219199-small1067229.gif',
#    'user_name': 'FMJ',
#    'name_color': '2264D6',
#    'content': '許願：\n投票功能\n預約發噗\n改善時光機功能\n一鍵全消音',
#    'posted': 'Fri, 12 Jul 2019 04:29:37 GMT'},
#   {'user_id': '3321299',
#    'user_img': 'https://avatars.plurk.com/3321299-small0.gif',
#    'user_name': '啊嗚封狼',
#    'name_color': None,
#    'content': '--先做個投票功能來投之後要上什麼新功能--',
#    'posted': 'Fri, 12 Jul 2019 04:29:56 GMT'},
#   {'user_id': '6674829',
#    'user_img': 'https://avatars.plurk.com/6674829-small23183414.gif',
#    'user_name': '斐静🍛不動明王',
#    'name_color': '0A9C17',
#    'content': '我也要許願自己跟別人的私噗能分開 [emo205] ',
#    'posted': 'Fri, 12 Jul 2019 04:45:37 GMT'},
#   {'user_id': '9829398',
#    'user_img': 'https://avatars.plurk.com/9829398-small9034492.gif',
#    'user_name': '娜塔利亞🌈人生が崩壊大ピンチ',
#    'name_color': 'E8AF37',
#    'content': '許願排程發噗和批量刪噗功能[emo235]',
#    'posted': 'Fri, 12 Jul 2019 04:48:48 GMT'},
#   {'user_id': '9406603',
#    'user_img': 'https://avatars.plurk.com/9406603-small22208582.gif',
#    'user_name': '椰可❖草青',
#    'name_color': '63C6D3',
#    'content': '@ciaos70302: 原來如此，謝謝回答！',
#    'posted': 'Fri, 12 Jul 2019 05:06:14 GMT'},
#   {'user_id': '4711100',
#    'user_img': 'https://avatars.plurk.com/4711100-small20.gif',
#    'user_name': 'smile_Q 🗝🌌🌏✏',
#    'name_color': None,
#    'content': '河道可以filter朋友跟追蹤的人+1',
#    'posted': 'Fri, 12 Jul 2019 05:13:27 GMT'},
#   {'user_id': '9072295',
#    'user_img': 'https://avatars.plurk.com/9072295-small21466233.gif',
#    'user_name': '小栗星人ʕ•ᴥ•ʔ',
#    'name_color': '63C6D3',
#    'content': '想要私人河道可以單獨開放某些噗是公開的（有時候要求票比較方便～）',
#    'posted': 'Fri, 12 Jul 2019 05:14:35 GMT'},
#   {'user_id': '14200528',
#    'user_img': 'https://avatars.plurk.com/14200528-small13376954.gif',
#    'user_name': '脆脆的餅乾',
#    'name_color': None,
#    'content': '許願投票功能+1[emo27]......',
#    'posted': 'Fri, 12 Jul 2019 05:17:22 GMT'},
#   {'user_id': '3853572',
#    'user_img': 'https://avatars.plurk.com/3853572-small148.gif',
#    'user_name': 'Kira♥卍σ`∀´)σ卍😈',
#    'name_color': 'BA8FBE',
#    'content': '許願有選擇公開的相簿功能🙏',
#    'posted': 'Fri, 12 Jul 2019 05:43:21 GMT'},
#   {'user_id': '6643890',
#    'user_img': 'https://avatars.plurk.com/6643890-small17469153.gif',
#    'user_name': '海苔🥦',
#    'name_color': '86CA6F',
#    'content': '許願\n投票功能+一鍵消音',
#    'posted': 'Fri, 12 Jul 2019 05:45:24 GMT'},
#   {'user_id': '14869847',
#    'user_img': 'https://avatars.plurk.com/14869847-small16966883.gif',
#    'user_name': '園咲来人',
#    'name_color': '0A9C17',
#    'content': '許願排程發噗',
#    'posted': 'Fri, 12 Jul 2019 06:05:19 GMT'},
#   {'user_id': '4651746',
#    'user_img': 'https://avatars.plurk.com/4651746-small24.gif',
#    'user_name': 'Barier',
#    'name_color': 'E41227',
#    'content': '許願所有頁面的圖片縮圖圓角能改回方角，或至少允許在自訂佈景能修改',
#    'posted': 'Fri, 12 Jul 2019 07:23:53 GMT'},
#   {'user_id': '365688',
#    'user_img': 'https://avatars.plurk.com/365688-small6239701.gif',
#    'user_name': 'Ayukawayen',
#    'name_color': '2264D6',
#    'content': '自訂佈景可以改吧?\n`.plurk a.pictureservices, .plurk a.meta img { border-radius: 0; }`',
#    'posted': 'Fri, 12 Jul 2019 07:33:24 GMT'},
#   {'user_id': '4651746',
#    'user_img': 'https://avatars.plurk.com/4651746-small24.gif',
#    'user_name': 'Barier',
#    'name_color': 'E41227',
#    'content': '@Ayukawayen: 點開噗文裡的縮圖與單一頁面的縮圖改不了耶，有噗友幫忙看過自訂佈景的語法，回覆說修改重整後，仍會讀取回官方的圓角數值',
#    'posted': 'Fri, 12 Jul 2019 07:38:17 GMT'},
#   {'user_id': '365688',
#    'user_img': 'https://avatars.plurk.com/365688-small6239701.gif',
#    'user_name': 'Ayukawayen',
#    'name_color': '2264D6',
#    'content': '@barier: 單一頁面好像沒在套用自訂佈景，所以應該是改不了沒錯 XD',
#    'posted': 'Fri, 12 Jul 2019 07:45:13 GMT'},
#   {'user_id': '4516729',
#    'user_img': 'https://avatars.plurk.com/4516729-small32.gif',
#    'user_name': '人生就是吃吃睡睡',
#    'name_color': 'E41227',
#    'content': '分流++\n希望可以裏帳號不用另外創',
#    'posted': 'Fri, 12 Jul 2019 09:23:58 GMT'},
#   {'user_id': '5676522',
#    'user_img': 'https://avatars.plurk.com/5676522-small54.gif',
#    'user_name': '❄銀雪∞',
#    'name_color': '86CA6F',
#    'content': '@sh98coco: 例如不想被家人朋友知道自己半夜還在用電腦但怕隔天忘記本來想發的東西的時候',
#    'posted': 'Fri, 12 Jul 2019 09:50:48 GMT'},
#   {'user_id': '9406603',
#    'user_img': 'https://avatars.plurk.com/9406603-small22208582.gif',
#    'user_name': '椰可❖草青',
#    'name_color': '63C6D3',
#    'content': '@ginyuki92: 原來如此！謝謝！',
#    'posted': 'Fri, 12 Jul 2019 10:17:09 GMT'},
#   {'user_id': '15172521',
#    'user_img': 'https://avatars.plurk.com/15172521-small22083230.gif',
#    'user_name': 'royalmunchkinkats',
#    'name_color': None,
#    'content': 'Munchkin cats for sale just visit my website munchkin.company.com',
#    'posted': 'Fri, 12 Jul 2019 11:46:55 GMT'},
#   {'user_id': '4994174',
#    'user_img': 'https://avatars.plurk.com/4994174-small22952623.gif',
#    'user_name': '天坑仙貓台🐈 藻藻鏡',
#    'name_color': 'BA8FBE',
#    'content': '許願投票功能',
#    'posted': 'Fri, 12 Jul 2019 11:58:40 GMT'},
#   {'user_id': '15062465',
#    'user_img': 'https://avatars.plurk.com/15062465-small20332271.gif',
#    'user_name': '🐵🙈🙉🙊',
#    'name_color': 'BA8FBE',
#    'content': '[emo98]',
#    'posted': 'Fri, 12 Jul 2019 12:01:24 GMT'},
#   {'user_id': '15199692',
#    'user_img': 'https://avatars.plurk.com/15199692-small22684931.gif',
#    'user_name': '太阳花',
#    'name_color': None,
#    'content': 'https://images.plurk.com/5dzkdMpNnVrKMGyR5RYN8C.jpg',
#    'posted': 'Mon, 15 Jul 2019 08:38:31 GMT'},
#   {'user_id': '3714315',
#    'user_img': 'https://avatars.plurk.com/3714315-small52.gif',
#    'user_name': 'zsupper',
#    'name_color': 'E41227',
#    'content': '噗浪的字好像變小了,在所有社群裡是最小的,而且還不能調',
#    'posted': 'Mon, 15 Jul 2019 13:50:05 GMT'}]}

# %%
##################### 
#                   #
#      Makedown     #
#                   #
#####################

md_file = MdUtils(file_name='plurk_test',title='plurk_test_v0')

md_file.new_paragraph("![U](" + raw_data['plurk']['poster_img'] + ")")
md_file.write(raw_data['plurk']['poster_name'], bold_italics_code='b', color='#DDDDDD')
md_file.new_line(raw_data['plurk']['post_content'])
md_file.new_line(raw_data['plurk']['post_time'])
md_file.write('\n___')

md_file.new_line(str(raw_data['plurk']['response_count'])+'則回應',color='#E8E8E8')
for i in raw_data['response']:
    md_file.new_paragraph("![U]("+i['user_img']+")")

    if i['name_color'] == None:
        md_file.write(i['user_name'], bold_italics_code='b', color='#DDDDDD')        
    else:
        md_file.write(i['user_name'], bold_italics_code='b', color='#'+i['name_color'])

    md_file.new_line(i['content'])
    md_file.new_line(i['posted'])

md_file.create_md_file()
